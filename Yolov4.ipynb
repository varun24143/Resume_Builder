# %%
# %cd /content/drive/MyDrive/yolov4
# Out:
# /content/drive/MyDrive/yolov4

# %%
import os
os.chdir("/content/drive/MyDrive/yolov4/darknet")
os.getcwd()
# Out:
# '/content/drive/MyDrive/yolov4/darknet'

# %% [markdown]
# #Make changes to the makefile

# %%
# !make
# Out:
# chmod +x *.sh

# %%
os.system("chmod +x ./darknet")
# Out:
# 0

# %% [markdown]
# #Train Yolov4 model

# %%
import os
import subprocess
import sys

# with open('test.log', 'wb') as f:
command = "./darknet detector train data/obj.data cfg/yolov4-custom.cfg yolov4.conv.137 -dont_show -map | tee output.log"
process = subprocess.Popen([command], stdout=subprocess.PIPE, shell=True,stderr=subprocess.STDOUT)
for line in process.stdout:
  sys.stdout.write(line)
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  CUDNN_HALF=1
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
# ...

# %% [markdown]
# #Test yolov4

# %%
# !chmod +x ./darknet
# !./darknet detector test data/obj.data cfg/yolov4-custom.cfg backup/yolov4-custom_best.weights

# %%
# %cd /content/drive/MyDrive/yolov4
# Out:
# /content/drive/MyDrive/yolov4

# %% [markdown]
# # Change the weights from yolov4 repo to yolov4-custom functions

# %%
# !cp darknet/backup/yolov4-custom_best.weights yolov4-custom-functions/data/custom.weights

# %%
import os
os.chdir("/content/drive/MyDrive/yolov4/yolov4-custom-functions")

# %%
# !cp ./darknet/backup/yolov4-custom_best.weights ./yolov4-custom-functions/data/custom.weights

# %%
pip install pytesseract

# %% [markdown]
# #Convert yolo weights to tensorflow weights

# %%
# !python save_model.py --weights ./data/custom.weights --output ./checkpoints/custom-608 --input_size 608 --model yolov4

# %% [markdown]
# #Object detection using tensorflow model

# %%
# !python detect.py --weights ./checkpoints/custom-608 --size 608 --model yolov4 --images /content/drive/MyDrive/yolov4/yolov4-custom-functions/images/_219__0.png

# %% [markdown]
# #Crop all images in a given folder

# %%
import os
import subprocess
directory = "/content/drive/MyDrive/yolov4/yolov4-custom-functions/images/"
for filename in os.listdir(directory):
  f = os.path.join(directory, filename)
  name,_ = filename.split('.')
  cmd = "python detect.py --weights ./checkpoints/custom-608 --size 608 --model yolov4 --images "+f+" --crop"
  p = os.system(cmd)
  print("Image Cropped")
# Out:
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped
# Image Cropped

# %%
# !apt install tesseract-ocr
# !apt install libtesseract-dev
# !pip install Pillow
# !pip install pytesseract

# %% [markdown]
# # Image to text conversion

# %%
import pytesseract
from PIL import ImageEnhance, ImageFilter, Image

import pytesseract
import cv2
import matplotlib.pyplot as plt
from PIL import Image

json = {}
directory = "/content/drive/MyDrive/yolov4/yolov4-custom-functions/detections/crop/"
for filename in os.listdir(directory):
  f = os.path.join(directory, filename)
  name = ''.join(filename)
  json[name] = {}
  for image in os.listdir(f):
    path = os.path.join(f,image)
    field,_ = image.split('.')
    text = pytesseract.image_to_string(Image.open(path), lang="eng")
    text = text.replace("\n","").replace("\x0c","")
    json[name][field] = text
print(json)
# Out:
# {'dog': {'bicycle_1': ' ', 'dog_1': ' ', 'truck_1': ' '}, '_test_resume-2__2': {}, '_test_resume-2__1': {'education_1': "EducationCFAI UniversityPUTER SCIENCE ENGINEERING, CGPA: 9.17/10  INTERMEDIATE, PERCENTAGE: 93.4%DrK.K.r's Gowtham Concept SchoolSECONDARY EDUCATION, GPA: 9.2yderabed int", 'skills_1': 'EducationICFAI UniversityCCouPuteR SCIENCE ENGINEERING, COPA: 9.17/10Sri Chaintanya junior collegeIivTeRMEDIAT, PERCENTAGE: 83.4%Dr-K.K.r’s Gowtham Concept SchoolSECONDARY EDUCATION, GPA: 9.2', 'skills_2': 'yderboa indoyderabod indoyderbod indo', 'experience_1': "CoursesDocker and Kubernetes: The Complete Guide.+ Bul test, and deploy Docker applications with Kubemetes while leaning production style development worklowsEthereum and Soliity: The Complete Developer's GuideSTEPHEN GrDER+ Ethereum, Slit, and Smart Contracts to built productions‘The Complete Node,js Developer Coursevonew Hed, Row PERCHA.+ Lean Node} by building rel erid application wth Node, Express, MongoDB, Jest and mor
# ...

# %% [markdown]
# #Json response

# %%
import pprint
pprint.pprint(json)
# Out:
# {'_159__0': {'name_1': 'Nehal Singh',
#              'name_2': 'CURRICULUM VITAE',
#              'summary_1': 'AREER OBJECTIVEeking a position to apply the '
#                           'knowledge that | have leed explore abilities, '
#                           'skills, towards my duties and to excant laa,'},
#  '_159__1': {},
#  '_169__0': {'name_1': 'MAHESH SEHGAL', 'skills_1': 'SKILLSrrr oat ona ee'},
#  '_183__0': {'education_1': '  Institute / College /SchoolMonth & Yearof '
#                             'passingSPL/% Marks& Chass Obtaine [B.Tech | sem '
#                             'IB.Tech sem [B.Tech semIndian Institute '
#                             'ofInformation lB.Tech 1v semTechnology Dharwad '
#                             'lB-Tech V sem lB.Tech vi sem[December '
#                             '2018,66      May 2019 7.December 2019 704[May '
#                             '2020 821[December 2020 a4 May 2021  intermediate! '
# ...

# %% [markdown]
# #Structured

# %%
pip install pytesseract
# Out:
# ...
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14072 sha256=bf63611ce7e7c27628ed8b5a6c3c1e14561a8bead42c76f9e33eed461d740a55
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# ...

# %%
import os
import subprocess
import sys

root = "/content/drive/MyDrive/yolov4"

#change dir to darknet
os.chdir(os.path.join(root,"darknet"))

#Access to darknet
os.system("chmod +x ./darknet")

# Train the model
# command = "./darknet detector train data/obj.data cfg/yolov4-custom.cfg yolov4.conv.137 -dont_show -map | tee output.log"
# process = subprocess.Popen([command], stdout=subprocess.PIPE, shell=True,stderr=subprocess.STDOUT)
# for line in process.stdout:
#   sys.stdout.write(line.decode('utf-8'))

#Get the best saved model to yolov4-custom-functions
os.chdir(root)
p = os.system("cp ./darknet/backup/yolov4-custom_best.weights ./yolov4-custom-functions/data/custom.weights")
print(p)
print("Moved the weights")

#change dir to yolov4-custom-functions
os.chdir(os.path.join(root,"yolov4-custom-functions"))

#Change darknet model to tensorflow model
command = "python save_model.py --weights ./data/custom.weights --output ./checkpoints/custom-416 --input_size 416 --model yolov4"
process = subprocess.Popen([command], stdout=subprocess.PIPE, shell=True,stderr=subprocess.STDOUT)
for line in process.stdout:
  sys.stdout.write(line)

#Crop detected portions
print("Cropping test images")
image_paths_file = os.path.join(root,'darknet/data/test.txt')
im_paths = open(image_paths_file, "r").readlines()

for i in im_paths:
  i = str(i).replace("\n","")
  cmd = "python detect.py --weights ./checkpoints/custom-416 --size 416 --model yolov4 --images "+i+" --crop"
  p = os.system(cmd)
  print("Cropped Image")
# Out:
# 0
# Moved the weights
# 2021-10-25 06:49:12.813028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 06:49:13.249450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 06:49:13.250567: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-25 06:49:13.252175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
